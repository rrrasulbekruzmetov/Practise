# %% [markdown]
# # API orqali malumotlarni olish

# %% [markdown]
# # API - bu Application Programming Interface

# %% [markdown]
# # trading botlar
# # weather apps
# # news aggregators
# # automation systems

# %% [markdown]
# # Muhim 3 ta tushuncha
# - API Key bu - ruxsat kaliti
# - requests - server bilan aloqa qilish
# - JSON - structured data

# %%
import requests

api_key = "1fa4d01598114272b7c69c162ad3a8e9"
city = "Tashkent"

url = f"https://api.openweathermap.org/data/2.5/weather?q={city}&appid={api_key}&units=metric"

response =  requests.get(url)
data = response.json()

print(data)
print("City: ", data["name"])
print("Temp: ", data["main"]["temp"])
print("Weather: ", data["weather"][0]["description"])
# Out:
# {'cod': 401, 'message': 'Invalid API key. Please see https://openweathermap.org/faq#error401 for more info.'}
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[11], line 12
#       9 data = response.json()
#      11 print(data)
# ---> 12 print("City: ", data["name"])
#      13 print("Temp: ", data["main"]["temp"])
#      14 print("Weather: ", data["weather"][0]["description"])
#
# KeyError: 'name'

# %%
import requests

api_key = "6b610bda22b1425d96a9d79608780b45"

url = "https://newsapi.org/v2/top-headlines"

params = {
    "country": "us",
    "apiKey": api_key
}

response = requests.get(url, params=params)
data = response.json()

print(data)
# Out:
# {'status': 'ok', 'totalResults': 37, 'articles': [{'source': {'id': None, 'name': 'Spaceflight Now'}, 'author': None, 'title': 'West Coast SpaceX Falcon 9 mission launches 25 Starlink satellites - Spaceflight Now', 'description': None, 'url': 'https://spaceflightnow.com/2026/04/15/west-coast-spacex-falcon-9-mission-to-launch-25-starlink-satellites/', 'urlToImage': None, 'publishedAt': '2026-04-15T07:27:59Z', 'content': 'A Falcon 9 rocket stands poised to launch from the Space Launch Complex 4E at Vandenberg Space Force Base in California. File Photo: SpaceX\r\nSpaceX launched a Falcon 9 rocket from Vandenberg Space Fo… [+937 chars]'}, {'source': {'id': 'cbs-news', 'name': 'CBS News'}, 'author': 'Brian  Dakss, Haley  Ott, Sarah  Lynch Baldwin', 'title': 'Live Updates: U.S. says blockade of Iranian ports "fully implemented" as Trump weighs more talks with Iran - CBS News', 'description': 'CENTCOM commander Adm. Brad Cooper says a blockade of Iranian ports "has been fully implemented," 
# ...

# %%
import requests

api_key = "6b610bda22b1425d96a9d79608780b45"

url = "https://newsapi.org/v2/top-headlines"

params = {
    "country": "bg",
    "apiKey": api_key
}

response = requests.get(url, params=params)
data = response.json()

print(data)
# Out:
# {'status': 'ok', 'totalResults': 0, 'articles': []}

# %%
url = "https://newsapi.org/v2/everything"

params = {
    "q": "artificial intelligence",
    "apiKey": api_key
}


response = requests.get(url, params=params)
data = response.json()


for article in data["articles"][:50]:
    print(article["title"])
# Out:
# Nvidia CEO Jensen Huang says ‘I think we’ve achieved AGI’
# Why people really hate AI
# Senators Elizabeth Warren and Josh Hawley Push for Data Center Energy Transparency
# Melania Trump Escorted by Talking Humanoid Robot at White House Tech Summit
# Kash Patel Admits the FBI is Buying Private Data on Americans
# How AI could destroy — or save — humanity, according to former AI insiders
# How AI is helping solo founders make their first hires
# I saw the AI apocalypse documentary. It made the stakes of the new technology feel even higher.
# Trump wants a deadlocked Congress to move on AI. Frustrated states say they already have
# Prediction: This Artificial Intelligence (AI) Stock Will Skyrocket After March 18 (Hint: It's Not Micron)
# The Artificial Intelligence (AI) Stock Most Likely to Mint New Millionaires
# 1 No-Brainer Artificial Intelligence (AI) Stock That Will Skyrocket By the End of 2026
# 2 Artificial Intelligence (AI) Stocks That Could Set You Up for Life
# ...

# %%
# !pip install streamlit

# %%
import sys 
# !{sys.executable} -m pip install streamlit

# %%
import streamlit as st 
print("Streamlit ishlashni boshladi")
# Out:
# Streamlit ishlashni boshladi
