# %% [markdown]
# # WEB SCRAPPING

# %% [markdown]
# # Web Scrapping - bu turli manbalardan statik va dinamik ko`rinishdagi malumotlarni olish

# %% [markdown]
# # DATA EXRACTION

# %% [markdown]
# # Data Extraction - bu xom (raw) malumotlarni truli manbalardan olib chiqib, keyingi ishlov berish jarayoni (preprocessing) uchun tayyorlash

# %% [markdown]
# # Dataset olishning 2 usuli mavjud
#
# - 1-Usul  ## API orqali olish
#
# - JSON - strukturali
# - Tezkor
# - Legal
#
#
# - 2-Usul - ## WEB SCRAPPING
# - HTML parsing
# - Blocklangan holatlar
# - Dynamic saytlardan malumot yigish murakkabligi

# %% [markdown]
# # Data Manbalari
#
# 1) Fayllar
# - CSV
# - Excel
# - JSON
# - Images
#
#
# 2) Database
#
# - MySQL
# - POSTGRE SQL
# - MONGO DB
# - SQL Express
#
# 3) API
#
# - REST API
# - Graph QL
#
#
# 4) WEB
# - Web Scrapping

# %% [markdown]
# # Data Extraction turlari
#
# 1) Structures Data
# - Jadval ko`rinishida  (csv, sql)
#
# 2) Semi- Structured
# - JSON, XML
#
# 3) Unstructured
# - Text
# - Image
# - Audio
