# %% [markdown]
# # CodeSpace Nima?

# %% [markdown]
# # Codespace - bu gut hub codespaces tamonidan taqdim etiladigan  cloud (bulutli) dasturlash muhiti bo`lib, bizga lokal pc siz ham to`liq IDE (VSCODE) ichida ishlash imkonini beradigan narsa

# %% [markdown]
# # Codespace bu - tayyor virtual muhit desak ham bo`ladi
