# %% [markdown]
# # Ko`p ishimiz tushadigan terminlarni bilib olish

# %% [markdown]
# # Terminlar
# - o`zgaruvchi  - o`zgaruvchi bu malumotni saqlovchi va ishlatuvchi narsa
#
# x = 10
#
#
# - funksiya -  bu qayta qayta ishlatish imkonini beruvchi kodlar blogi
#
# def add(a,b):
#     return a + b
#
# print(add(2, 3))
#
#
# - OOP  - object oriented programming - obyektga yo`nltirilgan dasturlash
#
# Dasturlashni obyektlar orqali tashkil qilish usuli - bu esa  katta loyihlarda kodlarni tartibli va oson boshqariladigan qiladi
#
# - Class  - bu shablon (template) -- class bu obyekt yaratish uchun shablon
# misol uchun class = mashina qolipi
# object = real mashina
#
# class Car:
#     def __init__(self, name):
#         self.name = name
#
#     def drive(self):
#         print(self.name, "yurishni boshladi")
#
# c1 = Car("BMW")
# c1.drive()

# %%
class Car: 
    def __init__(self, name):
        self.name = name 

    def drive(self):
        print(self.name, "yurishni boshladi")

c1 = Car("BMW")
c1.drive()
# Out:
# BMW yurishni boshladi

# %% [markdown]
# | Tushuncha   | Nima qiladi              |
# | ----------- | ------------------------ |
# | O‘zgaruvchi | Ma’lumot saqlaydi        |
# | Funksiya    | Ish bajaradi             |
# | Class       | Strukturani belgilaydi   |
# | OOP         | Tizimli dasturlash usuli |

# %% [markdown]
# # Algaritm - muammoni yechish uchun qadamlar ketma ketligi
# -  ishi: model qanday o`rganishini belgilaydi
# - misol: Linear Regression, Decision Tree

# %% [markdown]
# # Model - o`rganilgan formula yoki tizim
# - ishi: yangi malumotlarga qarab predict qiladi
# - misol: Random Forest, CNN , joblib pkl modellar

# %% [markdown]
# # Dataset - malumotlar to`plami
# - ishi: modelni o`qitadi
# - misol: rasmlar, raqamlar, textlar

# %% [markdown]
# # Feature - bu belgilar (data ichidagi muhim xusisiyatlar)
# - ishi: model qaror qilishda foydalanadi
# - misol: rasmdagi ranglar, textdagi so`zlar

# %% [markdown]
# # Label - bu target
# - ishi: modelni nazorat bilan o`rgatadi
# - misol: DL da mushuk yoki it,

# %% [markdown]
# # Workflow - bu pipeline (ishlarning ketma ket qadamlari)
# - bosqichma bosqich jarayon

# %% [markdown]
# # Preprocessing - bu datani tayyorlash
# - tozalash, normalize qilish

# %% [markdown]
# # Training - modelni o`rgatish
# # Validation - modelni tekshirish jarayoni  (training paytida)
# # Testing  - yakuniy sinov (model qanchalik yaxshi ishlashini baholash)

# %% [markdown]
# # Deployment - modelni real tizimga qo`yish
# - foydalanuvchi bemalol ishlata oladigan qilish

# %% [markdown]
# # Software  - dasturlar (kodlar) - python, tensorflow

# %% [markdown]
# # Hardware - fizik qurilmalar (hisoblashni bajaradi) , CPU , GPU

# %% [markdown]
# # GPU  - grafik protsessor

# %% [markdown]
# # Framework  - tayyor kutubxona
# - kod yozishni osonlashtiradi

# %% [markdown]
# # Architechture -  modelning tuzilmasi qanday qatlamlar bilan ishlashini belgilaydi

# %% [markdown]
# # Structure - tuzilma
# - ichki tashkil etilishi
# - tizimni tartibga soladi

# %% [markdown]
# # Layout - vizual joylashuv

# %% [markdown]
# # Layer - qatlam , modelning bo`lagi, featurelarni bosqichma bosqich o`rganadi

# %% [markdown]
# # Metod - bu class ichida yozilgan funksiya
# - funksiya = mustaqil ishlaydi
# - method = classga tegishli bo`ladi (object orqali chaqiriladi)
