# %% [markdown]
# # SML da workflow

# %% [markdown]
# - Define Problem
# - Data Collection
# - EDA
# - Data Preprocessing
# - Feature Enginering
# - Algaritm Selection
# - Model Training
# - Evaluation Model
# - Tuning
# - Interpret the model (Shap Analysis)
# - Make Prediction
# - Save the Model
# - Deployment

# %% [markdown]
# # UNS ML Workflow

# %% [markdown]
# - Define Problem
# - Data Collection
# - EDA
# - Data Preprocessing
# - Algaritmn Selection
# - Evaluate
# - Vizualization
# - Reporting
# - Combine with SML
