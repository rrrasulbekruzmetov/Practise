# %% [markdown]
# # Auto Pipeline + Log bilan ishlash

# %%
import logging
import os

# Log fayl manzili
log_file = r"C:\Users\Rasulbekk\Desktop\Practise\Log\sample.log"

# Log fayl papkasi borligini tekshirish
os.makedirs(os.path.dirname(log_file), exist_ok=True)

# Logging konfiguratsiyasi
logging.basicConfig(
    filename=log_file,
    filemode='a',   # append mode
    level=logging.INFO,
    format='%(asctime)s - %(levelname)s - %(message)s'
)

logging.info("Notebook ishga tushdi")

# %%
from auto_pipeline import Auto_Pipeline
import pandas as pd
from sklearn.ensemble import RandomForestClassifier


file_path = r"C:\Users\Rasulbekk\Desktop\Practise\Data\train.csv"
df = pd.read_csv(file_path)

import sys
sys.path.append(r"C:\Users\Rasulbekk\Desktop\Practise\Source")

from auto_pipeline import Auto_Pipeline
import pandas as pd
from sklearn.ensemble import RandomForestClassifier
logging.info("Pipeline klass import qilindi")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 from auto_pipeline import Auto_Pipeline
#       2 import pandas as pd
#       3 from sklearn.ensemble import RandomForestClassifier
#
# File ~\Desktop\Practise\Source\auto_pipeline.py:88
#      83 # -------------------------------
#      84 # Misol: RandomForest bilan ishlatish
#      85 from sklearn.ensemble import RandomForestClassifier
#      87 titanic_pipeline = Auto_Pipeline(
# ---> 88     df=df,
#      89     target='Survived',
#      90     model=RandomForestClassifier(n_estimators=100, random_state=42)
#      91 )
#      93 titanic_pipeline.fit()
#      94 preds = titanic_pipeline.predict()
#
# NameError: name 'df' is not defined
